# %% [markdown]
# # Vec KG RAG Evaluation Notebook\n\n用于快速调试 ingest/build/query/eval 结果。

# %%
from pathlib import Path\nfrom vec_kg_rag.io_utils import read_json\n\nreport = read_json(Path('../artifacts/eval_report.json'))\nreport['top5_hit_rate'], report['citation_coverage']

# %%
report['details'][:3]
